# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## A Test Project containing data on testing for COVID-19 by week and Country

# %%
data = pd.read_csv(r"data.csv")

# %% [markdown]
# * The below displays the data as a whole

# %%
data
# Out:
#        YearWeekISO ReportingCountry  Denominator  NumberDosesReceived  \
# 0         2021-W01               AT    1392642.0                  0.0
# 1         2022-W23               AT     676675.0                  0.0
# 2         2021-W32               AT     424628.0                  0.0
# 3         2021-W32               AT     260101.0                  0.0
# 4         2021-W32               AT     676675.0                  0.0
# ...            ...              ...          ...                  ...
# 816548    2022-W37               SK     285322.0                  0.0
# 816549    2022-W37               SK    4402238.0                  0.0
# 816550    2022-W36               SK     686528.0                  0.0
# 816551    2022-W36               SK     702343.0                  0.0
# 816552    2022-W36               SK    2030544.0                  0.0
#
#         NumberDosesExported  FirstDose  FirstDoseRefused  SecondDose  \
# ...

# %%
data.columns
# Out:
# Index(['YearWeekISO', 'ReportingCountry', 'Denominator', 'NumberDosesReceived',
#        'NumberDosesExported', 'FirstDose', 'FirstDoseRefused', 'SecondDose',
#        'DoseAdditional1', 'DoseAdditional2', 'DoseAdditional3',
#        'DoseAdditional4', 'DoseAdditional5', 'UnknownDose', 'Region',
#        'TargetGroup', 'Vaccine', 'Population'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Denominator  NumberDosesReceived  NumberDosesExported     FirstDose  \
# count  4.399690e+05         1.091210e+05         1.071020e+05  8.165530e+05
# mean   1.505455e+06         1.378115e+04         8.455105e+02  1.143299e+03
# std    4.870745e+06         1.763487e+05         3.991602e+04  2.317336e+04
# min    0.000000e+00         0.000000e+00         0.000000e+00  0.000000e+00
# 25%    9.200300e+04         0.000000e+00         0.000000e+00  0.000000e+00
# 50%    2.728510e+05         0.000000e+00         0.000000e+00  0.000000e+00
# 75%    1.035517e+06         0.000000e+00         0.000000e+00  1.000000e+00
# max    6.937386e+07         1.889280e+07         6.488820e+06  4.021725e+06
#
#        FirstDoseRefused    SecondDose  DoseAdditional1  DoseAdditional2  \
# count       1447.000000  8.165530e+05     8.165530e+05     8.165530e+05
# mean           0.401520  1.040389e+03     8.251367e+02     2.210402e+02
# ...

# %%
data.isnull().sum()
# Out:
# YearWeekISO                 0
# ReportingCountry            0
# Denominator            376584
# NumberDosesReceived    707432
# NumberDosesExported    709451
# FirstDose                   0
# FirstDoseRefused       815106
# SecondDose                  0
# DoseAdditional1             0
# DoseAdditional2             0
# DoseAdditional3             0
# DoseAdditional4             0
# DoseAdditional5             0
# UnknownDose                 0
# Region                      0
# TargetGroup                 0
# Vaccine                     0
# Population                  0
# dtype: int64

# %% [markdown]
# # Relating the variables with scatterplot

# %%
sns.relplot(x="NumberDosesReceived", y="NumberDosesExported", data=data)
